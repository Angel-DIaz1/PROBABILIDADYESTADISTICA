# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-DIaz1/PROBABILIDADYESTADISTICA/blob/main/practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![nuevo_logos.png](data:image/png;base64,...)
#
#
#
#
#
#
# **Probabilidad y estadistica**
#
# unidad 1
#
# practica 4 tabla de frecuencias
#
# facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Miguel Angel Cordero Diaz

# %%
import random
#Creamos una lista vacia de 100 personas
edades = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 18, 70)
  #agregamos ell numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [30, 28, 40, 65, 37, 36, 22, 53, 49, 41, 63, 49, 21, 18, 45, 39, 29, 65, 64, 51, 21, 32, 59, 67, 60, 22, 69, 44, 18, 66, 42, 36, 43, 28, 64, 19, 45, 64, 21, 18, 38, 19, 19, 62, 50, 43, 69, 48, 22, 66, 56, 26, 51, 37, 70, 19, 66, 34, 26, 45, 52, 19, 65, 54, 31, 39, 41, 54, 68, 54, 26, 36, 35, 24, 67, 46, 52, 63, 40, 54, 46, 50, 56, 29, 44, 32, 54, 47, 64, 69, 59, 49, 69, 66, 62, 63, 38, 41, 65, 50]

# %%
import pandas as pd

df = pd.DataFrame(edades, columns = ['Edad'])
df.head()
# Out:
#    Edad
# 0    30
# 1    28
# 2    40
# 3    65
# 4    37

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de la Distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de la Distribucion de frecuencias:
#     Edad  Frecuencia
# 9     18           3
# 1     19           5
# 6     21           3
# 7     22           3
# 32    24           1
# 14    26           3
# 23    28           2
# 28    29           2
# 36    30           1
# 35    31           1
# 31    32           2
# 37    34           1
# 33    35           1
# 10    36           3
# 27    37           2
# 19    38           2
# 29    39           2
# 20    40           2
# 12    41           3
# 40    42           1
# 21    43           2
# 16    44           2
# 15    45           3
# 30    46           2
# 43    47           1
# 39    48           1
# 13    49           3
# 8     50           3
# 26    51           2
# 25    52           2
# 42    53           1
# 0     54           5
# 17    56           2
# 24    59           2
# 41    60           1
# 18    62           2
# 11    63           3
# 2     64           4
# 5     65           4
# 3     66           4
# 22    67           2
# 34    68           1
# 4     69           4
# 38    70           1

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 9     18           3           0.03
# 1     19           5           0.05
# 6     21           3           0.03
# 7     22           3           0.03
# 32    24           1           0.01
# 14    26           3           0.03
# 23    28           2           0.02
# 28    29           2           0.02
# 36    30           1           0.01
# 35    31           1           0.01
# 31    32           2           0.02
# 37    34           1           0.01
# 33    35           1           0.01
# 10    36           3           0.03
# 27    37           2           0.02
# 19    38           2           0.02
# 29    39           2           0.02
# 20    40           2           0.02
# 12    41           3           0.03
# 40    42           1           0.01
# 21    43           2           0.02
# 16    44           2           0.02
# 15    45           3           0.03
# 30    46           2           0.02
# 43    47           1           0.01
# 39    48           1           0.01
# 13    49           3           0.03
# 8     50           3           0.03
# 26    51           2           0.02
# 25    52           2           0.02
# 42    53           1           0.01
# 0     54           5           0.05
# 17    56           2           0.02
# 24    59           2           0.02
# 41    60           1           0.01
# 18    62           2           0.02
# 11    63           3           0.03
# 2     64           4           0.04
# 5     65           4           0.04
# 3     66           4           0.04
# 22    67           2           0.02
# 34    68           1           0.01
# 4     69           4           0.04
# 38    70           1           0.01

# %%
tabla_frecuencias['frec porcentual'] = tabla_frecuencias['Frecuencia'] /100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  frec porcentual
# 9     18           3           0.03              3.0
# 1     19           5           0.05              5.0
# 6     21           3           0.03              3.0
# 7     22           3           0.03              3.0
# 32    24           1           0.01              1.0
# 14    26           3           0.03              3.0
# 23    28           2           0.02              2.0
# 28    29           2           0.02              2.0
# 36    30           1           0.01              1.0
# 35    31           1           0.01              1.0
# 31    32           2           0.02              2.0
# 37    34           1           0.01              1.0
# 33    35           1           0.01              1.0
# 10    36           3           0.03              3.0
# 27    37           2           0.02              2.0
# 19    38           2           0.02              2.0
# 29    39           2           0.02              2.0
# 20    40           2           0.02              2.0
# 12    41           3           0.03              3.0
# 40    42           1           0.01              1.0
# 21    43           2           0.02              2.0
# 16    44           2           0.02              2.0
# 15    45           3           0.03              3.0
# 30    46           2           0.02              2.0
# 43    47           1           0.01              1.0
# 39    48           1           0.01              1.0
# 13    49           3           0.03              3.0
# 8     50           3           0.03              3.0
# 26    51           2           0.02              2.0
# 25    52           2           0.02              2.0
# 42    53           1           0.01              1.0
# 0     54           5           0.05              5.0
# 17    56           2           0.02              2.0
# 24    59           2           0.02              2.0
# 41    60           1           0.01              1.0
# 18    62           2           0.02              2.0
# 11    63           3           0.03              3.0
# 2     64           4           0.04              4.0
# 5     65           4           0.04              4.0
# 3     66           4           0.04              4.0
# 22    67           2           0.02              2.0
# 34    68           1           0.01              1.0
# 4     69           4           0.04              4.0
# 38    70           1           0.01              1.0

# %%
tabla_frecuencias['frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  frec porcentual  frec acumulada
# 9     18           3           0.03              3.0               3
# 1     19           5           0.05              5.0               8
# 6     21           3           0.03              3.0              11
# 7     22           3           0.03              3.0              14
# 32    24           1           0.01              1.0              15
# 14    26           3           0.03              3.0              18
# 23    28           2           0.02              2.0              20
# 28    29           2           0.02              2.0              22
# 36    30           1           0.01              1.0              23
# 35    31           1           0.01              1.0              24
# 31    32           2           0.02              2.0              26
# 37    34           1           0.01              1.0              27
# 33    35           1           0.01              1.0              28
# 10    36           3           0.03              3.0              31
# 27    37           2           0.02              2.0              33
# 19    38           2           0.02              2.0              35
# 29    39           2           0.02              2.0              37
# 20    40           2           0.02              2.0              39
# 12    41           3           0.03              3.0              42
# 40    42           1           0.01              1.0              43
# 21    43           2           0.02              2.0              45
# 16    44           2           0.02              2.0              47
# 15    45           3           0.03              3.0              50
# 30    46           2           0.02              2.0              52
# 43    47           1           0.01              1.0              53
# 39    48           1           0.01              1.0              54
# 13    49           3           0.03              3.0              57
# 8     50           3           0.03              3.0              60
# 26    51           2           0.02              2.0              62
# 25    52           2           0.02              2.0              64
# 42    53           1           0.01              1.0              65
# 0     54           5           0.05              5.0              70
# 17    56           2           0.02              2.0              72
# 24    59           2           0.02              2.0              74
# 41    60           1           0.01              1.0              75
# 18    62           2           0.02              2.0              77
# 11    63           3           0.03              3.0              80
# 2     64           4           0.04              4.0              84
# 5     65           4           0.04              4.0              88
# 3     66           4           0.04              4.0              92
# 22    67           2           0.02              2.0              94
# 34    68           1           0.01              1.0              95
# 4     69           4           0.04              4.0              99
# 38    70           1           0.01              1.0             100

# %%
import math
print(edades)
df= pd.DataFrame({'edad': edades})
df
# Out:
# [30, 28, 40, 65, 37, 36, 22, 53, 49, 41, 63, 49, 21, 18, 45, 39, 29, 65, 64, 51, 21, 32, 59, 67, 60, 22, 69, 44, 18, 66, 42, 36, 43, 28, 64, 19, 45, 64, 21, 18, 38, 19, 19, 62, 50, 43, 69, 48, 22, 66, 56, 26, 51, 37, 70, 19, 66, 34, 26, 45, 52, 19, 65, 54, 31, 39, 41, 54, 68, 54, 26, 36, 35, 24, 67, 46, 52, 63, 40, 54, 46, 50, 56, 29, 44, 32, 54, 47, 64, 69, 59, 49, 69, 66, 62, 63, 38, 41, 65, 50]
#     edad
# 0     30
# 1     28
# 2     40
# 3     65
# 4     37
# ..   ...
# 95    63
# 96    38
# 97    41
# 98    65
# 99    50
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int( 1 + math.log2(100))
print("valor de n=", n ,"\nNUmeros de intervalos=", K)
# Out:
# valor de n= 100
# NUmeros de intervalos= 7

# %%
tabla_frecuencias = pd.cut( df['edad'],bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase','Frec']
tabla_frecuencias
# Out:
#               clase  Frec
# 0    (62.571, 70.0]    23
# 1  (47.714, 55.143]    17
# 2  (17.947, 25.429]    15
# 3  (40.286, 47.714]    14
# 4  (32.857, 40.286]    13
# 5  (25.429, 32.857]    11
# 6  (55.143, 62.571]     7

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by='clase')
tabla_frecuencias
# Out:
#               clase  Frec
# 2  (17.947, 25.429]    15
# 5  (25.429, 32.857]    11
# 4  (32.857, 40.286]    13
# 3  (40.286, 47.714]    14
# 1  (47.714, 55.143]    17
# 6  (55.143, 62.571]     7
# 0    (62.571, 70.0]    23

# %%
tabla_frecuencias['Frec rel'] = tabla_frecuencias['Frec'] /n
tabla_frecuencias['Frec porc'] = tabla_frecuencias['Frec'] /n * 100
tabla_frecuencias['Frec ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec rel ac'] = tabla_frecuencias['Frec rel'].cumsum()
tabla_frecuencias['Frec porc ac'] = tabla_frecuencias['Frec porc'].cumsum()
print(tabla_frecuencias)
# Out:
#               clase  Frec  Frec rel  Frec porc  Frec ac  Frec rel ac  \
# 2  (17.947, 25.429]    15      0.15       15.0       15         0.15
# 5  (25.429, 32.857]    11      0.11       11.0       26         0.26
# 4  (32.857, 40.286]    13      0.13       13.0       39         0.39
# 3  (40.286, 47.714]    14      0.14       14.0       53         0.53
# 1  (47.714, 55.143]    17      0.17       17.0       70         0.70
# 6  (55.143, 62.571]     7      0.07        7.0       77         0.77
# 0    (62.571, 70.0]    23      0.23       23.0      100         1.00
#
#    Frec porc ac
# 2          15.0
# 5          26.0
# 4          39.0
# 3          53.0
# 1          70.0
# 6          77.0
# 0         100.0
