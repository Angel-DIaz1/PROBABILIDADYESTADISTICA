# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-DIaz1/PROBABILIDADYESTADISTICA/blob/main/Unidad1_Practica_1_y_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![nuevo_logos.png](data:image/png;base64,...)
#
#
#
#
#
#
# **Probabilidad y estadistica**
#
# unidad 1
#
# practica 1 y 2
#
# facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Miguel Angel Cordero Diaz

# %%
from statistics import *
# lista de calificaciones del grupo a de probabilidad y estadistica
grupos = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupos)

type(grupos)

promedio = sum(grupos) / len(grupos)
print(promedio)

promedio2 = mean(grupos)
print(promedio2)

mediana = median(grupos)
print(mediana)

moda = mode(grupos)
print(moda)

moda2 = multimode(grupos)
print(moda2)

tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100mts)

print("el tiempo promedio de los corredores es=>", mean(tiempos100mts) )

mediana = median(tiempos100mts)
print("la media de los  tiempos de los corredores es=>", mediana )

moda = multimode(tiempos100mts)
print(" la moda de los tiempos es=>", moda)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# el tiempo promedio de los corredores es=> 17.322
# la media de los  tiempos de los corredores es=> 17.2
#  la moda de los tiempos es=> [15.1, 17.2]

# %%
import random

fabrica1 = []
for i in range(100):
   numero_aleatorio = round( random.uniform(50, 100), 2)
   fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [90.42, 59.29, 68.7, 82.52, 57.27, 86.48, 71.0, 70.71, 98.33, 55.29, 96.45, 61.21, 63.56, 91.04, 54.87, 75.37, 65.4, 85.52, 67.96, 67.73, 82.06, 86.82, 75.28, 64.07, 56.19, 62.64, 62.33, 58.09, 81.93, 56.04, 53.25, 58.74, 60.28, 71.64, 95.73, 72.96, 70.4, 75.29, 72.21, 78.55, 88.66, 81.65, 88.05, 55.11, 79.24, 78.48, 99.63, 75.6, 82.71, 92.35, 77.12, 71.72, 97.5, 71.12, 84.54, 98.81, 50.43, 89.15, 83.23, 60.36, 95.63, 80.49, 52.38, 90.29, 96.73, 66.65, 68.5, 99.79, 80.65, 57.17, 51.79, 91.02, 72.83, 60.06, 65.22, 78.18, 85.99, 53.45, 57.89, 66.85, 70.62, 93.12, 91.64, 78.6, 64.3, 93.78, 57.38, 60.97, 82.16, 69.57, 56.34, 76.34, 69.69, 83.81, 68.32, 99.95, 71.97, 75.2, 91.03, 76.77]

# %%
import random

fabrica2 = []
for i in range(100):
   numero_aleatorio = round( random.uniform(50, 100), 2)
   fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [72.02, 75.68, 92.84, 52.46, 73.19, 66.02, 96.65, 92.2, 89.87, 97.37, 74.86, 83.58, 92.43, 83.65, 50.81, 67.41, 85.95, 54.03, 97.94, 58.73, 65.63, 84.75, 82.95, 58.65, 92.2, 85.19, 79.32, 51.95, 78.6, 51.51, 52.59, 84.32, 86.24, 80.07, 65.76, 92.83, 54.63, 64.15, 80.07, 77.49, 57.98, 78.6, 55.7, 60.58, 95.53, 85.26, 83.87, 66.85, 62.04, 56.32, 62.66, 95.42, 59.23, 50.09, 93.35, 53.17, 85.46, 72.01, 93.06, 56.57, 82.42, 86.97, 92.83, 99.05, 98.4, 77.05, 82.18, 98.94, 87.4, 91.44, 53.68, 82.56, 73.62, 93.6, 94.18, 75.11, 63.66, 93.17, 94.31, 65.32, 86.71, 91.64, 59.18, 89.36, 61.3, 91.16, 81.31, 51.64, 58.33, 88.55, 52.25, 91.2, 74.03, 82.51, 51.13, 53.76, 96.43, 98.01, 89.2, 69.21]

# %%
import matplotlib.pyplot as plt


plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt

plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 2')

# %%
from statistics import *

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("valores de la fabrica 1")
print("la media es =", media1)
print("la mediana es =", mediana1)
print("la moda es=", moda1)
# Out:
# valores de la fabrica 1
# la media es = 74.722
# la mediana es = 74.08
# la moda es= 90.42

# %%
from statistics import *

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("valores de la fabrica 2")
print("la media es =", media2)
print("la mediana es =", mediana2)
print("la moda es=", moda2)
# Out:
# valores de la fabrica 2
# la media es = 76.5314
# la mediana es = 80.07
# la moda es= 92.2

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 2")
plt.legend()
plt.show()
