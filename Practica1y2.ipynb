# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-DIaz1/PROBABILIDADYESTADISTICA/blob/main/Practica1y2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import *
# lista de calificaciones del grupo a de probabilidad y estadistica
grupos = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupos)

type(grupos)

promedio = sum(grupos) / len(grupos)
print(promedio)

promedio2 = mean(grupos)
print(promedio2)

mediana = median(grupos)
print(mediana)

moda = mode(grupos)
print(moda)

moda2 = multimode(grupos)
print(moda2)

tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100mts)

print("el tiempo promedio de los corredores es=>", mean(tiempos100mts) )

mediana = median(tiempos100mts)
print("la media de los  tiempos de los corredores es=>", mediana )

moda = multimode(tiempos100mts)
print(" la moda de los tiempos es=>", moda)

import random

fabrica1 = []
for i in range(100):
   numero_aleatorio = round( random.uniform(50, 100), 2)
   fabrica1.append(numero_aleatorio)
print(fabrica1)

import random

fabrica2 = []
for i in range(100):
   numero_aleatorio = round( random.uniform(50, 100), 2)
   fabrica2.append(numero_aleatorio)
print(fabrica2)

import matplotlib.pyplot as plt


plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")

import matplotlib.pyplot as plt

plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")

from statistics import *

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("valores de la fabrica 1")
print("la media es =", media1)
print("la mediana es =", mediana1)
print("la moda es=", moda1)
from statistics import *

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("valores de la fabrica 2")
print("la media es =", media2)
print("la mediana es =", mediana2)
print("la moda es=", moda2)

fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 1")
plt.legend()
plt.show()

plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 2")
plt.legend()
plt.show()
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# el tiempo promedio de los corredores es=> 17.322
# la media de los  tiempos de los corredores es=> 17.2
#  la moda de los tiempos es=> [15.1, 17.2]
# [92.58, 68.72, 64.56, 65.23, 86.33, 58.44, 80.72, 70.89, 94.41, 54.41, 83.04, 90.14, 55.88, 53.06, 61.4, 71.93, 70.89, 72.59, 69.87, 51.08, 58.36, 60.09, 83.21, 65.6, 58.77, 67.0, 90.48, 67.92, 76.64, 76.89, 76.82, 68.51, 68.7, 77.81, 80.22, 52.97, 96.08, 63.66, 90.71, 79.42, 59.67, 91.1, 87.08, 76.57, 96.39, 68.21, 97.67, 86.51, 52.92, 65.01, 89.8, 64.38, 80.48, 65.41, 83.95, 63.92, 92.0, 79.34, 80.65, 88.08, 78.81, 93.65, 54.63, 84.84, 81.51, 70.04, 77.08, 86.16, 60.29, 83.03, 94.4, 59.99, 98.02, 93.48, 62.25, 93.62, 92.81, 61.89, 88.3, 64.99, 93.27, 88.33, 96.24, 81.5, 84.92, 55.48, 55.71, 77.21, 60.92, 67.93, 56.66, 74.9, 98.77, 51.37, 52.57, 65.4, 54.83, 55.28, 98.21, 68.22]
# [55.37, 92.02, 77.57, 62.79, 85.22, 52.27, 56.46, 71.55, 81.4, 71.36, 88.03, 64.32, 93.56, 50.81, 74.34, 65.73, 56.72, 78.5, 74.4, 63.11, 53.7, 56.09, 57.47, 57.26, 68.11, 86.69, 63.56, 96.69, 76.0, 63.2, 82.15, 92.35, 89.68, 71.79, 98.08, 56.98, 67.45, 59.59, 51.87, 75.26, 88.9, 56.01, 59.01, 59.65, 63.31, 67.49, 93.59, 71.15, 98.09, 60.89, 85.87, 61.67, 61.36, 66.67, 74.48, 98.43, 86.33, 60.87, 72.49, 66.33, 92.41, 82.31, 69.26, 57.75, 81.59, 88.1, 73.35, 98.76, 86.4, 81.99, 62.13, 72.14, 63.21, 52.14, 96.75, 67.23, 72.72, 78.56, 60.56, 82.03, 93.59, 61.92, 94.26, 99.83, 56.94, 74.83, 65.98, 82.21, 60.29, 77.66, 66.25, 61.71, 86.54, 89.71, 91.62, 86.17, 54.67, 95.2, 50.72, 69.34]
# valores de la fabrica 1
# la media es = 74.6268
# la mediana es = 75.735
# la moda es= 70.89
# valores de la fabrica 2
# la media es = 73.3092
# la mediana es = 71.67
# la moda es= 93.59
