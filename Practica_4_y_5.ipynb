# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-DIaz1/PROBABILIDADYESTADISTICA/blob/main/Practica_4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![nuevo_logos.png](data:image/png;base64,...)
#
#
#
#
#
#
# **Probabilidad y estadistica**
#
# unidad 1
#
# practica 4 tabla de frecuencias
#
# facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Miguel Angel Cordero Diaz

# %%
import random
#Creamos una lista vacia de 100 personas
edades = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 18, 70)
  #agregamos ell numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [23, 57, 48, 45, 65, 53, 49, 49, 44, 70, 55, 64, 33, 32, 38, 64, 55, 47, 45, 47, 21, 60, 34, 44, 61, 59, 20, 49, 24, 70, 59, 19, 20, 47, 55, 52, 40, 65, 22, 22, 41, 18, 56, 50, 55, 63, 63, 47, 28, 68, 45, 58, 48, 52, 52, 31, 19, 23, 24, 38, 19, 30, 63, 30, 30, 53, 19, 53, 67, 57, 48, 52, 70, 63, 30, 62, 22, 54, 25, 20, 56, 32, 58, 42, 28, 67, 58, 57, 64, 69, 22, 51, 45, 19, 25, 37, 53, 50, 48, 40]

# %%
import pandas as pd

df = pd.DataFrame(edades, columns = ['Edad'])
df.head()
# Out:
#    Edad
# 0    23
# 1    57
# 2    48
# 3    45
# 4    65

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de la Distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de la Distribucion de frecuencias:
#     Edad  Frecuencia
# 33    18           1
# 0     19           5
# 15    20           3
# 30    21           1
# 2     22           4
# 22    23           2
# 23    24           2
# 18    25           2
# 17    28           2
# 5     30           4
# 34    31           1
# 28    32           2
# 35    33           1
# 31    34           1
# 43    37           1
# 24    38           2
# 21    40           2
# 36    41           1
# 40    42           1
# 26    44           2
# 7     45           4
# 4     47           4
# 8     48           4
# 10    49           3
# 19    50           2
# 42    51           1
# 9     52           4
# 6     53           4
# 38    54           1
# 1     55           4
# 20    56           2
# 13    57           3
# 14    58           3
# 27    59           2
# 29    60           1
# 39    61           1
# 37    62           1
# 3     63           4
# 12    64           3
# 25    65           2
# 16    67           2
# 32    68           1
# 41    69           1
# 11    70           3

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 33    18           1           0.01
# 0     19           5           0.05
# 15    20           3           0.03
# 30    21           1           0.01
# 2     22           4           0.04
# 22    23           2           0.02
# 23    24           2           0.02
# 18    25           2           0.02
# 17    28           2           0.02
# 5     30           4           0.04
# 34    31           1           0.01
# 28    32           2           0.02
# 35    33           1           0.01
# 31    34           1           0.01
# 43    37           1           0.01
# 24    38           2           0.02
# 21    40           2           0.02
# 36    41           1           0.01
# 40    42           1           0.01
# 26    44           2           0.02
# 7     45           4           0.04
# 4     47           4           0.04
# 8     48           4           0.04
# 10    49           3           0.03
# 19    50           2           0.02
# 42    51           1           0.01
# 9     52           4           0.04
# 6     53           4           0.04
# 38    54           1           0.01
# 1     55           4           0.04
# 20    56           2           0.02
# 13    57           3           0.03
# 14    58           3           0.03
# 27    59           2           0.02
# 29    60           1           0.01
# 39    61           1           0.01
# 37    62           1           0.01
# 3     63           4           0.04
# 12    64           3           0.03
# 25    65           2           0.02
# 16    67           2           0.02
# 32    68           1           0.01
# 41    69           1           0.01
# 11    70           3           0.03

# %%
tabla_frecuencias['frec porcentual'] = tabla_frecuencias['Frecuencia'] /100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  frec porcentual
# 33    18           1           0.01              1.0
# 0     19           5           0.05              5.0
# 15    20           3           0.03              3.0
# 30    21           1           0.01              1.0
# 2     22           4           0.04              4.0
# 22    23           2           0.02              2.0
# 23    24           2           0.02              2.0
# 18    25           2           0.02              2.0
# 17    28           2           0.02              2.0
# 5     30           4           0.04              4.0
# 34    31           1           0.01              1.0
# 28    32           2           0.02              2.0
# 35    33           1           0.01              1.0
# 31    34           1           0.01              1.0
# 43    37           1           0.01              1.0
# 24    38           2           0.02              2.0
# 21    40           2           0.02              2.0
# 36    41           1           0.01              1.0
# 40    42           1           0.01              1.0
# 26    44           2           0.02              2.0
# 7     45           4           0.04              4.0
# 4     47           4           0.04              4.0
# 8     48           4           0.04              4.0
# 10    49           3           0.03              3.0
# 19    50           2           0.02              2.0
# 42    51           1           0.01              1.0
# 9     52           4           0.04              4.0
# 6     53           4           0.04              4.0
# 38    54           1           0.01              1.0
# 1     55           4           0.04              4.0
# 20    56           2           0.02              2.0
# 13    57           3           0.03              3.0
# 14    58           3           0.03              3.0
# 27    59           2           0.02              2.0
# 29    60           1           0.01              1.0
# 39    61           1           0.01              1.0
# 37    62           1           0.01              1.0
# 3     63           4           0.04              4.0
# 12    64           3           0.03              3.0
# 25    65           2           0.02              2.0
# 16    67           2           0.02              2.0
# 32    68           1           0.01              1.0
# 41    69           1           0.01              1.0
# 11    70           3           0.03              3.0

# %%
tabla_frecuencias['frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  frec porcentual  frec acumulada
# 33    18           1           0.01              1.0               1
# 0     19           5           0.05              5.0               6
# 15    20           3           0.03              3.0               9
# 30    21           1           0.01              1.0              10
# 2     22           4           0.04              4.0              14
# 22    23           2           0.02              2.0              16
# 23    24           2           0.02              2.0              18
# 18    25           2           0.02              2.0              20
# 17    28           2           0.02              2.0              22
# 5     30           4           0.04              4.0              26
# 34    31           1           0.01              1.0              27
# 28    32           2           0.02              2.0              29
# 35    33           1           0.01              1.0              30
# 31    34           1           0.01              1.0              31
# 43    37           1           0.01              1.0              32
# 24    38           2           0.02              2.0              34
# 21    40           2           0.02              2.0              36
# 36    41           1           0.01              1.0              37
# 40    42           1           0.01              1.0              38
# 26    44           2           0.02              2.0              40
# 7     45           4           0.04              4.0              44
# 4     47           4           0.04              4.0              48
# 8     48           4           0.04              4.0              52
# 10    49           3           0.03              3.0              55
# 19    50           2           0.02              2.0              57
# 42    51           1           0.01              1.0              58
# 9     52           4           0.04              4.0              62
# 6     53           4           0.04              4.0              66
# 38    54           1           0.01              1.0              67
# 1     55           4           0.04              4.0              71
# 20    56           2           0.02              2.0              73
# 13    57           3           0.03              3.0              76
# 14    58           3           0.03              3.0              79
# 27    59           2           0.02              2.0              81
# 29    60           1           0.01              1.0              82
# 39    61           1           0.01              1.0              83
# 37    62           1           0.01              1.0              84
# 3     63           4           0.04              4.0              88
# 12    64           3           0.03              3.0              91
# 25    65           2           0.02              2.0              93
# 16    67           2           0.02              2.0              95
# 32    68           1           0.01              1.0              96
# 41    69           1           0.01              1.0              97
# 11    70           3           0.03              3.0             100

# %%
import math
print(edades)
df= pd.DataFrame({'edad': edades})
df
# Out:
# [23, 57, 48, 45, 65, 53, 49, 49, 44, 70, 55, 64, 33, 32, 38, 64, 55, 47, 45, 47, 21, 60, 34, 44, 61, 59, 20, 49, 24, 70, 59, 19, 20, 47, 55, 52, 40, 65, 22, 22, 41, 18, 56, 50, 55, 63, 63, 47, 28, 68, 45, 58, 48, 52, 52, 31, 19, 23, 24, 38, 19, 30, 63, 30, 30, 53, 19, 53, 67, 57, 48, 52, 70, 63, 30, 62, 22, 54, 25, 20, 56, 32, 58, 42, 28, 67, 58, 57, 64, 69, 22, 51, 45, 19, 25, 37, 53, 50, 48, 40]
#     edad
# 0     23
# 1     57
# 2     48
# 3     45
# 4     65
# ..   ...
# 95    37
# 96    53
# 97    50
# 98    48
# 99    40
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int( 1 + math.log2(100))
print("valor de n=", n ,"\nNUmeros de intervalos=", K)
# Out:
# valor de n= 100
# NUmeros de intervalos= 7

# %%
tabla_frecuencias = pd.cut( df['edad'],bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase','Frec']
tabla_frecuencias
# Out:
#               clase  Frec
# 0  (47.714, 55.143]    23
# 1  (17.947, 25.429]    20
# 2    (62.571, 70.0]    16
# 3  (55.143, 62.571]    13
# 4  (40.286, 47.714]    12
# 5  (25.429, 32.857]     9
# 6  (32.857, 40.286]     7

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by='clase')
tabla_frecuencias
# Out:
#               clase  Frec
# 1  (17.947, 25.429]    20
# 5  (25.429, 32.857]     9
# 6  (32.857, 40.286]     7
# 4  (40.286, 47.714]    12
# 0  (47.714, 55.143]    23
# 3  (55.143, 62.571]    13
# 2    (62.571, 70.0]    16

# %%
tabla_frecuencias['Frec rel'] = tabla_frecuencias['Frec'] /n
tabla_frecuencias['Frec porc'] = tabla_frecuencias['Frec'] /n * 100
tabla_frecuencias['Frec ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec rel ac'] = tabla_frecuencias['Frec rel'].cumsum()
tabla_frecuencias['Frec porc ac'] = tabla_frecuencias['Frec porc'].cumsum()
print(tabla_frecuencias)
# Out:
#               clase  Frec  Frec rel  Frec porc  Frec ac  Frec rel ac  \
# 1  (17.947, 25.429]    20      0.20       20.0       20         0.20
# 5  (25.429, 32.857]     9      0.09        9.0       29         0.29
# 6  (32.857, 40.286]     7      0.07        7.0       36         0.36
# 4  (40.286, 47.714]    12      0.12       12.0       48         0.48
# 0  (47.714, 55.143]    23      0.23       23.0       71         0.71
# 3  (55.143, 62.571]    13      0.13       13.0       84         0.84
# 2    (62.571, 70.0]    16      0.16       16.0      100         1.00
#
#    Frec porc ac
# 1          20.0
# 5          29.0
# 6          36.0
# 4          48.0
# 0          71.0
# 3          84.0
# 2         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5, bins = 20 )
plt.title("histograma de edades nasado en la funcion de mathplotlib coon valores estandar")
# Out:
# Text(0.5, 1.0, 'histograma de edades nasado en la funcion de mathplotlib coon valores estandar')

# %%
plt.hist(df['edad'], bins=K, alpha = 0.5)
plt.title('histograma de edades baasdo en la regla de sturges')
plt.xlabel('Edades')
plt.xlabel('Frecuencia')
# Out:
# Text(0.5, 0, 'Frecuencia')

# %% [markdown]
# Practica 5 diagrama de cajas y bigotes

# %%
import random
#Creamos una lista vacia de 100 personas
edades2 = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 20, 87)
  #agregamos el numero aleatorio a la lista de valores
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [27, 75, 45, 45, 74, 36, 57, 36, 58, 65, 61, 87, 85, 63, 58, 57, 43, 42, 72, 72, 32, 34, 34, 81, 67, 62, 56, 39, 68, 35, 45, 55, 44, 35, 23, 36, 34, 31, 27, 60, 73, 60, 32, 39, 49, 85, 44, 44, 21, 44, 85, 53, 71, 54, 55, 77, 79, 60, 20, 38, 20, 41, 82, 39, 66, 23, 54, 85, 30, 31, 23, 69, 39, 25, 52, 39, 59, 69, 81, 66, 47, 52, 25, 86, 50, 23, 74, 34, 39, 45, 40, 55, 42, 58, 39, 42, 28, 60, 63, 29]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
